# %% [markdown]
# # Accesing Data

# %% [markdown]
# Find 3 datasets of interest to you that are provided in different file formats. Choose datasets that are not too big, so that they do not take more than a few second to load. At least one dataset, must have non numerical (eg string or boolean) data in at least 1 column. Complete a dictionary for each with the url, a name, and what function should be used to load the data into a pandas.DataFrame.

# %%
# imports
import pandas as pd

# %%
# Three disctionaries for three websites

d1 = {'url':'https://www.numbeo.com/quality-of-life/rankings_by_country.jsp',
     'name': 'rankings_by_country',
     'load_func': lambda URL: pd.read_html(URL)[1]}
                                   
#what function should be used to load the data into a pandas.DataFrame
#.what should be input of func?url?
    
d2 = {'url': 'https://en.wikipedia.org/wiki/List_of_best-selling_music_artists' ,
     'name': 'List_of_best-selling_music_artists' ,
     'load_func': lambda URL: pd.read_html(URL)[0]}

d3 = {'url': 'https://finance.yahoo.com/quote/TSLA/history' ,
     'name': 'history',
     'load_func': lambda URL: pd.read_html(URL)[0]}
#d3['url']

# %%
# Making a list of dictionaries

datasets_info_dict =[d1, d2, d3]

# %% [markdown]
# ## Dataset summary

# %%
website_1 = pd.read_html(d1['url'])

# %%
# df1 is the second index of website_1 list
df1 = d1['load_func'](d1['url'])

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.shape
# Out:
# (82, 11)

# %%
# Showing the first five components of data frame (df1)

df1.head()
# Out:
#    Rank      Country  Quality of Life Index  Purchasing Power Index  \
# 0   NaN      Denmark                 192.53                  101.27
# 1   NaN  Switzerland                 190.92                  114.83
# 2   NaN      Finland                 186.40                   93.94
# 3   NaN    Australia                 185.03                  103.38
# 4   NaN  Netherlands                 184.18                   86.76
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0         73.91              80.17                 85.02
# 1         78.42              73.10                125.69
# 2         74.47              75.96                 72.71
# 3         58.33              77.81                 75.89
# 4         72.85              75.68                 74.63
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            6.96                       28.93
# 1                            8.52                       28.93
# 2                            8.69                       29.41
# 3                            7.44                       35.00
# 4                            7.45                       28.15
#
#    Pollution Index  Climate Index
# 0            21.52          81.80
# 1            21.89          80.05
# 2            11.79          59.21
# 3            23.22          94.20
# 4            26.11          87.53

# %%
# Showing the last five components of data frame (df1)

df1.tail()
# Out:
#     Rank      Country  Quality of Life Index  Purchasing Power Index  \
# 77   NaN  Philippines                  79.18                   21.38
# 78   NaN         Iran                  70.32                   21.88
# 79   NaN        Kenya                  66.60                   28.98
# 80   NaN   Bangladesh                  66.29                   27.59
# 81   NaN      Nigeria                  54.91                   11.10
#
#     Safety Index  Health Care Index  Cost of Living Index  \
# 77         57.78              67.52                 39.25
# 78         51.09              52.23                 38.47
# 79         38.27              55.58                 37.75
# 80         36.18              43.08                 33.41
# 81         36.73              50.05                 29.76
#
#     Property Price to Income Ratio  Traffic Commute Time Index  \
# 77                           29.92                       44.60
# 78                           29.83                       47.44
# 79                           36.33                       56.96
# 80                           14.30                       59.01
# 81                           16.19                       62.14
#
#     Pollution Index  Climate Index
# 77            74.24          61.11
# 78            76.69          70.99
# 79            76.56          99.79
# 80            85.83          72.91
# 81            86.89          60.75

# %% [markdown]
# ### Display the heading with the last seven rows

# %%
df1.tail(7)
# Out:
#     Rank      Country  Quality of Life Index  Purchasing Power Index  \
# 75   NaN         Peru                  85.28                   30.66
# 76   NaN    Sri Lanka                  80.36                   21.42
# 77   NaN  Philippines                  79.18                   21.38
# 78   NaN         Iran                  70.32                   21.88
# 79   NaN        Kenya                  66.60                   28.98
# 80   NaN   Bangladesh                  66.29                   27.59
# 81   NaN      Nigeria                  54.91                   11.10
#
#     Safety Index  Health Care Index  Cost of Living Index  \
# 75         34.35              56.45                 37.64
# 76         59.77              72.44                 32.93
# 77         57.78              67.52                 39.25
# 78         51.09              52.23                 38.47
# 79         38.27              55.58                 37.75
# 80         36.18              43.08                 33.41
# 81         36.73              50.05                 29.76
#
#     Property Price to Income Ratio  Traffic Commute Time Index  \
# 75                           15.57                       48.81
# 76                           34.98                       56.95
# 77                           29.92                       44.60
# 78                           29.83                       47.44
# 79                           36.33                       56.96
# 80                           14.30                       59.01
# 81                           16.19                       62.14
#
#     Pollution Index  Climate Index
# 75            83.34          97.69
# 76            60.03          59.11
# 77            74.24          61.11
# 78            76.69          70.99
# 79            76.56          99.79
# 80            85.83          72.91
# 81            86.89          60.75

# %% [markdown]
# ### make and display a new data frame with only the non numerical columns

# %%
df1.select_dtypes(exclude='number').style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_918f1768_fb90_11ea_959e_f0421ce5e8ea" ><thead>    <tr>        <th class="col_heading level0 col0" >Country</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow0_col0" class="data row0 col0" >Denmark</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow1_col0" class="data row1 col0" >Switzerland</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow2_col0" class="data row2 col0" >Finland</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow3_col0" class="data row3 col0" >Australia</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow4_col0" class="data row4 col0" >Netherlands</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow5_col0" class="data row5 col0" >Austria</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow6_col0" class="data row6 col0" >Iceland</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow7_col0" class="data row7 col0" >New Zealand</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow8_col0" class="data row8 col0" >Germany</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow9_col0" class="data row9 col0" >Estonia</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow10_col0" class="data row10 col0" >Norway</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow11_col0" class="data row11 col0" >Oman</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow12_col0" class="data row12 col0" >Sweden</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow13_col0" class="data row13 col0" >Slovenia</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow14_col0" class="data row14 col0" >United States</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow15_col0" class="data row15 col0" >Spain</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow16_col0" class="data row16 col0" >Japan</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow17_col0" class="data row17 col0" >Portugal</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow18_col0" class="data row18 col0" >United Kingdom</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow19_col0" class="data row19 col0" >Lithuania</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow20_col0" class="data row20 col0" >Canada</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow21_col0" class="data row21 col0" >Qatar</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow22_col0" class="data row22 col0" >Croatia</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow23_col0" class="data row23 col0" >United Arab Emirates</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow24_col0" class="data row24 col0" >Czech Republic</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow25_col0" class="data row25 col0" >France</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow26_col0" class="data row26 col0" >Ireland</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow27_col0" class="data row27 col0" >Slovakia</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow28_col0" class="data row28 col0" >Belgium</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow29_col0" class="data row29 col0" >Saudi Arabia</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow30_col0" class="data row30 col0" >Latvia</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow31_col0" class="data row31 col0" >Israel</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow32_col0" class="data row32 col0" >Cyprus</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow33_col0" class="data row33 col0" >Singapore</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow34_col0" class="data row34 col0" >Taiwan</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow35_col0" class="data row35 col0" >Italy</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow36_col0" class="data row36 col0" >South Korea</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow37_col0" class="data row37 col0" >Belarus</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow38_col0" class="data row38 col0" >South Africa</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow39_col0" class="data row39 col0" >Romania</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow40_col0" class="data row40 col0" >Greece</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow41_col0" class="data row41 col0" >Puerto Rico</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow42_col0" class="data row42 col0" >Hungary</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow43_col0" class="data row43 col0" >Bulgaria</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow44_col0" class="data row44 col0" >Turkey</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow45_col0" class="data row45 col0" >Poland</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow46_col0" class="data row46 col0" >Uruguay</td>
#             </tr>
#             <tr>
#                                 <td id="T_918f1768_fb90_11ea_959e_f0421ce5e8earow47_col0" class="data ro

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=82, step=1)

# %%
df1.describe()
# Out:
#        Rank  Quality of Life Index  Purchasing Power Index  Safety Index  \
# count   0.0              82.000000               82.000000     82.000000
# mean    NaN             131.969146               56.062805     60.637561
# std     NaN              33.609472               25.868711     13.678326
# min     NaN              54.910000               11.100000     22.710000
# 25%     NaN             105.132500               33.717500     52.810000
# 50%     NaN             131.235000               51.425000     59.880000
# 75%     NaN             158.385000               79.202500     71.682500
# max     NaN             192.530000              114.830000     88.100000
#
#        Health Care Index  Cost of Living Index  \
# count          82.000000             82.000000
# mean           64.774268             52.412317
# std             9.918447             20.248250
# min            43.080000             21.000000
# 25%            56.697500             36.642500
# 50%            65.910000             49.060000
# 75%            72.500000             68.597500
# max            86.420000            125.690000
#
#        Property Price to Income Ratio  Traffic Commute Time Index  \
# count                       82.000000                   82.000000
# mean                        13.549512                   35.952927
# std                          7.516185                    8.243301
# min                          2.720000                   20.100000
# 25%                          8.705000                   29.920000
# 50%                         11.835000                   35.020000
# 75%                         16.035000                   39.750000
# max                         43.520000                   62.140000
#
#        Pollution Index  Climate Index
# count        82.000000      82.000000
# mean         53.490854      77.229268
# std          20.627157      16.185653
# min          11.790000      20.220000
# 25%          37.675000      68.970000
# 50%          57.300000      78.850000
# 75%          67.425000      89.862500
# max          88.910000      99.790000

# %% [markdown]
# ### Was the format that the data was provided in a good format? why or why not?

# %% [markdown]
# Yes. Because it was provided in rows and columns and data type was consistent in each column.

# %%
website_2 = pd.read_html(d2['url'])

# %%
df2 = d2['load_func'](d2['url'])
df2
# Out:
#             Artist       Country / Market                       Period active  \
# 0      The Beatles         United Kingdom                       1960–1970[10]
# 1    Elvis Presley          United States                       1954–1977[41]
# 2  Michael Jackson          United States                       1964–2009[53]
# 3       Elton John         United Kingdom                    1964–present[67]
# 4          Madonna          United States                    1979–present[74]
# 5     Led Zeppelin         United Kingdom                       1968–1980[83]
# 6          Rihanna  BarbadosUnited States                    2005–present[91]
# 7       Pink Floyd         United Kingdom  1965–1996, 2005, 2012–2014[98][99]
#
#   Release year of first charted record  \
# 0                             1962[10]
# 1                             1954[41]
# 2                             1971[53]
# 3                             1969[67]
# 4                             1982[74]
# 5                             1969[83]
# 6                             2005[91]
# 7                             1967[98]
#
#                                      Genre  \
# 0                           Rock / Pop[10]
# 1        Rock and roll / Pop / Country[41]
# 2      Pop / Rock / Dance / Soul / R&B[53]
# 3                           Pop / Rock[67]
# 4            Pop / Dance / Electronica[74]
# 5   Hard rock / Blues rock / Folk rock[83]
# 6          R&B / Pop / Dance / Hip-hop[91]
# 7  Progressive rock / Psychedelic rock[98]
#
#     Total certified units(from available markets)[a]  \
# 0  Total available certified units: 281 million U...
# 1  Total available certified units: 226.1 million...
# 2  Total available certified units: 233 million U...
# 3  Total available certified units: 193.1 million...
# 4  Total available certified units: 173.8 million...
# 5  Total available certified units: 141.3 million...
# 6  Total available certified units: 281.8 million...
# 7  Total available certified units: 121.5 million...
#
#                             Claimed sales
# 0      600 million[38][39]500 million[40]
# 1      600 million[50][51]500 million[52]
# 2  350 million[63][64]300 million[65][66]
# 3  300 million[70][71]250 million[72][73]
# 4      300 million[80][81]275 million[82]
# 5  300 million[87][88]200 million[89][90]
# 6                     250 million[96][97]
# 7   250 million[101][102]200 million[103]

# %% [markdown]
# ### Display the heading and the first three rows

# %%
df2.head(3)
# Out:
#             Artist Country / Market  Period active  \
# 0      The Beatles   United Kingdom  1960–1970[10]
# 1    Elvis Presley    United States  1954–1977[41]
# 2  Michael Jackson    United States  1964–2009[53]
#
#   Release year of first charted record                                Genre  \
# 0                             1962[10]                       Rock / Pop[10]
# 1                             1954[41]    Rock and roll / Pop / Country[41]
# 2                             1971[53]  Pop / Rock / Dance / Soul / R&B[53]
#
#     Total certified units(from available markets)[a]  \
# 0  Total available certified units: 281 million U...
# 1  Total available certified units: 226.1 million...
# 2  Total available certified units: 233 million U...
#
#                             Claimed sales
# 0      600 million[38][39]500 million[40]
# 1      600 million[50][51]500 million[52]
# 2  350 million[63][64]300 million[65][66]

# %% [markdown]
# ### display the datatype for each column

# %%
df2.dtypes
# Out:
# Artist                                              object
# Country / Market                                    object
# Period active                                       object
# Release year of first charted record                object
# Genre                                               object
# Total certified units(from available markets)[a]    object
# Claimed sales                                       object
# dtype: object

# %% [markdown]
# ### Are there any variables where pandas may have read in the data as a datatype that’s not what you expect (eg a numerical column mistaken for strings)?

# %% [markdown]
# no. all columns include non numerical characters.

# %%
website_3= pd.read_html(d3['url'])

# %%
df3 = d3['load_func'](d3['url'])
df3
# Out:
#                                                   Date  \
# 0                                         Sep 18, 2020
# 1                                         Sep 17, 2020
# 2                                         Sep 16, 2020
# 3                                         Sep 15, 2020
# 4                                         Sep 14, 2020
# ..                                                 ...
# 96                                        May 05, 2020
# 97                                        May 04, 2020
# 98                                        May 01, 2020
# 99                                        Apr 30, 2020
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                               447.94
# 1                                               415.60
# 2                                               439.87
# 3                                               436.56
# 4                                               380.95
# ..                                                 ...
# 96                                              157.96
# 97                                              140.20
# 98                                              151.00
# 99                                              171.04
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 0                                               451.00
# 1                                               437.79
# 2                                               457.79
# 3                                               461.94
# 4                                               420.00
# ..                                                 ...
# 96                                              159.78
# 97                                              152.40
# 98                                              154.55
# 99                                              173.96
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 0                                               428.80
# 1                                               408.00
# 2                                               435.31
# 3                                               430.70
# 4                                               373.30
# ..                                                 ...
# 96                                              152.44
# 97                                              139.60
# 98                                              136.61
# 99                                              152.70
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  \
# 0                                               442.15
# 1                                               423.43
# 2                                               441.76
# 3                                               449.76
# 4                                               419.62
# ..                                                 ...
# 96                                              153.64
# 97                                              152.24
# 98                                              140.26
# 99                                              156.38
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                            Adj Close**  \
# 0                                               442.15
# 1                                               423.43
# 2                                               441.76
# 3                                               449.76
# 4                                               419.62
# ..                                                 ...
# 96                                              153.64
# 97                                              152.24
# 98                                              140.26
# 99                                              156.38
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Volume
# 0                                             85995000
# 1                                             76779200
# 2                                             72279300
# 3                                             97298200
# 4                                             83020600
# ..                                                 ...
# 96                                            84958500
# 97                                            96185500
# 98                                           162659000
# 99                                           142359500
# 100  *Close price adjusted for splits.**Adjusted cl...
#
# [101 rows x 7 columns]

# %%
df3['Date']
# Out:
# 0                                           Sep 18, 2020
# 1                                           Sep 17, 2020
# 2                                           Sep 16, 2020
# 3                                           Sep 15, 2020
# 4                                           Sep 14, 2020
#                              ...
# 96                                          May 05, 2020
# 97                                          May 04, 2020
# 98                                          May 01, 2020
# 99                                          Apr 30, 2020
# 100    *Close price adjusted for splits.**Adjusted cl...
# Name: Date, Length: 101, dtype: object

# %% [markdown]
# ## Display the first 5 even rows of the data for three columns of your choice

# %%
df3[['Date','Low', 'Volume']].loc[::2].head()
# df3.Date.Low.Volume.loc[::2].head() #Does not work!
# Out:
#            Date     Low     Volume
# 0  Sep 18, 2020  428.80   85995000
# 2  Sep 16, 2020  435.31   72279300
# 4  Sep 14, 2020  373.30   83020600
# 6  Sep 10, 2020  360.56   84930600
# 8  Sep 08, 2020  329.88  115465700

# %% [markdown]
# ### Try reading it in with the wrong read_ function. If you had done this by accident, how could you tell?

# %%
website_3 = pd.read_csv('https://finance.yahoo.com/quote/TSLA/history')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-125-303908357747> in <module>
# ----> 1 website_3 = pd.read_csv('https://finance.yahoo.com/quote/TSLA/history')
#
# ~/anaconda3/envs/csc310/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/anaconda3/envs/csc310/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~/anaconda3/envs/csc310/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
#    1188         # May alter columns / col_dict
#
# ~/anaconda3/envs/csc310/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2143     def read(self, nrows=None):
#    2144         try:
# -> 2145             data = self._reader.read(nrows)
#    2146         except StopIteration:
#    2147             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 573 fields in line 13, saw 1562

# %% [markdown]
# I can undesrtand it by the error I am getting, as it says this fuction is not able to parse data

# %%
type(d1)

# %% [markdown]
#  Use a list of those dictionaries to iterate over the datasets and build a table that describes them, with the following columns ['name','source','num_rows', 'num_columns','source_file_name']. The source column should be the url where you loaded the data from or the source if you downloaded it from a website first The source_file_name should be the part of the url after the last /, you should extract this programmatically. Display that summary table as a dataframe and save it as a csv, named dataset_summary.csv.

# %%
a = []
b = []
c = []
d = []
e = []


for dic in datasets_info_dict:
    name_website = dic['name']
    address_website = dic['url'] 
    num_rows_df = dic['load_func'](dic['url'])[0]
    num_columns_df = dic['load_func'](dic['url'])[1]
#     if i==1:
#         num_rows_df = df1.shape[0]
#         num_columns_df = df1.shape[1]
#     elif i==2:
#         num_rows_df  = df2.shape[0]
#         num_columns_df = df2.shape[1]
#     elif i==3:
#         num_rows_df  = df3.shape[0]
#         num_columns_df = df3.shape[1]
    
    source_file_name_website = dic['url'].split('/')[-1]
    
    a.append(name_website)
    b.append(address_website)
    c.append(num_rows_df)
    d.append(num_columns_df)
    e.append(source_file_name_website)
    
    ex_dic = {'name' : a,
             'source' : b,
             'num_rows' : c,
             'num_columns' : d,
              'source_file_name' : e,
             }
columns = ['name', 'source', 'num_rows', 'num_columns', 'source_file_name']
index = ["d_1", "d_2", "d_3"]
df = pd.DataFrame(ex_dic, columns=columns, index=index)
df
df.to_csv('dataset_summary.csv') 
#print(ex_dic)

# %% [markdown]
# ## (for the process skill)
#
# ### Make a list of a data science pipeline and denote which types of programming might be helpful at each staged. Include this in a markdown cell in the same notebook with your analysis'''

# %% [markdown]
#     1. O — Obtaining our data (MySQL)
#     2. S — Scrubbing / Cleaning our data (Python or R)
#     3. E — Exploring / Visualizing our data will allow us to find patterns and trends (Numpy, Matplotlib, Pandas or Scipy)
#     4. M — Modeling our data will give us our predictive power as a wizard (Sci-kit Learn)
#     5. N — Interpreting our data
#
# [reference] (https://towardsdatascience.com/a-beginners-guide-to-the-data-science-pipeline-a4904b2d8ad3)
